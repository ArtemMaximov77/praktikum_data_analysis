# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Шаг-1.-Откройте-файл-с-данными-и-изучите-общую-информацию" data-toc-modified-id="Шаг-1.-Откройте-файл-с-данными-и-изучите-общую-информацию-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Шаг 1. Откройте файл с данными и изучите общую информацию</a></span></li><li><span><a href="#Шаг-2.-Подготовьте-данные" data-toc-modified-id="Шаг-2.-Подготовьте-данные-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Шаг 2. Подготовьте данные</a></span><ul class="toc-item"><li><span><a href="#Замените-названия-столбцов-(приведите-к-нижнему-регистру);" data-toc-modified-id="Замените-названия-столбцов-(приведите-к-нижнему-регистру);-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Замените названия столбцов (приведите к нижнему регистру);</a></span></li><li><span><a href="#Преобразуйте-данные-в-нужные-типы.-Опишите,-в-каких-столбцах-заменили-тип-данных-и-почему;" data-toc-modified-id="Преобразуйте-данные-в-нужные-типы.-Опишите,-в-каких-столбцах-заменили-тип-данных-и-почему;-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Преобразуйте данные в нужные типы. Опишите, в каких столбцах заменили тип данных и почему;</a></span></li><li><span><a href="#Обработайте-пропуски-при-необходимости;" data-toc-modified-id="Обработайте-пропуски-при-необходимости;-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Обработайте пропуски при необходимости;</a></span></li><li><span><a href="#Посчитайте-суммарные-продажи-во-всех-регионах-и-запишите-их-в-отдельный-столбец." data-toc-modified-id="Посчитайте-суммарные-продажи-во-всех-регионах-и-запишите-их-в-отдельный-столбец.-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Посчитайте суммарные продажи во всех регионах и запишите их в отдельный столбец.</a></span></li></ul></li><li><span><a href="#Шаг-3.-Проведите-исследовательский-анализ-данных" data-toc-modified-id="Шаг-3.-Проведите-исследовательский-анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Шаг 3. Проведите исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Посмотрите,-сколько-игр-выпускалось-в-разные-годы.-Важны-ли-данные-за-все-периоды?" data-toc-modified-id="Посмотрите,-сколько-игр-выпускалось-в-разные-годы.-Важны-ли-данные-за-все-периоды?-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Посмотрите, сколько игр выпускалось в разные годы. Важны ли данные за все периоды?</a></span></li><li><span><a href="#Посмотрите,-как-менялись-продажи-по-платформам.-Выберите-платформы-с-наибольшими-суммарными-продажами-и-постройте-распределение-по-годам.-За-какой-характерный-срок-появляются-новые-и-исчезают-старые-платформы?" data-toc-modified-id="Посмотрите,-как-менялись-продажи-по-платформам.-Выберите-платформы-с-наибольшими-суммарными-продажами-и-постройте-распределение-по-годам.-За-какой-характерный-срок-появляются-новые-и-исчезают-старые-платформы?-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Посмотрите, как менялись продажи по платформам. Выберите платформы с наибольшими суммарными продажами и постройте распределение по годам. За какой характерный срок появляются новые и исчезают старые платформы?</a></span></li><li><span><a href="#Возьмите-данные-за-соответствующий-актуальный-период.-Актуальный-период-определите-самостоятельно-в-результате-исследования-предыдущих-вопросов.-Основной-фактор-—-эти-данные-помогут-построить-прогноз-на-2017-год." data-toc-modified-id="Возьмите-данные-за-соответствующий-актуальный-период.-Актуальный-период-определите-самостоятельно-в-результате-исследования-предыдущих-вопросов.-Основной-фактор-—-эти-данные-помогут-построить-прогноз-на-2017-год.-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Возьмите данные за соответствующий актуальный период. Актуальный период определите самостоятельно в результате исследования предыдущих вопросов. Основной фактор — эти данные помогут построить прогноз на 2017 год.</a></span></li><li><span><a href="#Не-учитывайте-в-работе-данные-за-предыдущие-годы." data-toc-modified-id="Не-учитывайте-в-работе-данные-за-предыдущие-годы.-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Не учитывайте в работе данные за предыдущие годы.</a></span></li><li><span><a href="#Какие-платформы-лидируют-по-продажам,-растут-или-падают?-Выберите-несколько-потенциально-прибыльных-платформ." data-toc-modified-id="Какие-платформы-лидируют-по-продажам,-растут-или-падают?-Выберите-несколько-потенциально-прибыльных-платформ.-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Какие платформы лидируют по продажам, растут или падают? Выберите несколько потенциально прибыльных платформ.</a></span></li><li><span><a href="#Постройте-график-«ящик-с-усами»-по-глобальным-продажам-игр-в-разбивке-по-платформам.-Опишите-результат." data-toc-modified-id="Постройте-график-«ящик-с-усами»-по-глобальным-продажам-игр-в-разбивке-по-платформам.-Опишите-результат.-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Постройте график «ящик с усами» по глобальным продажам игр в разбивке по платформам. Опишите результат.</a></span></li><li><span><a href="#Посмотрите,-как-влияют-на-продажи-внутри-одной-популярной-платформы-отзывы-пользователей-и-критиков.-Постройте-диаграмму-рассеяния-и-посчитайте-корреляцию-между-отзывами-и-продажами.-Сформулируйте-выводы." data-toc-modified-id="Посмотрите,-как-влияют-на-продажи-внутри-одной-популярной-платформы-отзывы-пользователей-и-критиков.-Постройте-диаграмму-рассеяния-и-посчитайте-корреляцию-между-отзывами-и-продажами.-Сформулируйте-выводы.-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Посмотрите, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Постройте диаграмму рассеяния и посчитайте корреляцию между отзывами и продажами. Сформулируйте выводы.</a></span></li><li><span><a href="#Соотнесите-выводы-с-продажами-игр-на-других-платформах." data-toc-modified-id="Соотнесите-выводы-с-продажами-игр-на-других-платформах.-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>Соотнесите выводы с продажами игр на других платформах.</a></span></li><li><span><a href="#Посмотрите-на-общее-распределение-игр-по-жанрам.-Что-можно-сказать-о-самых-прибыльных-жанрах?-Выделяются-ли-жанры-с-высокими-и-низкими-продажами?" data-toc-modified-id="Посмотрите-на-общее-распределение-игр-по-жанрам.-Что-можно-сказать-о-самых-прибыльных-жанрах?-Выделяются-ли-жанры-с-высокими-и-низкими-продажами?-3.9"><span class="toc-item-num">3.9&nbsp;&nbsp;</span>Посмотрите на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами?</a></span></li></ul></li><li><span><a href="#Шаг-4.-Составьте-портрет-пользователя-каждого-региона" data-toc-modified-id="Шаг-4.-Составьте-портрет-пользователя-каждого-региона-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Шаг 4. Составьте портрет пользователя каждого региона</a></span><ul class="toc-item"><li><span><a href="#Самые-популярные-платформы-(топ-5).-Опишите-различия-в-долях-продаж." data-toc-modified-id="Самые-популярные-платформы-(топ-5).-Опишите-различия-в-долях-продаж.-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Самые популярные платформы (топ-5). Опишите различия в долях продаж.</a></span></li><li><span><a href="#Самые-популярные-жанры-(топ-5).-Поясните-разницу." data-toc-modified-id="Самые-популярные-жанры-(топ-5).-Поясните-разницу.-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Самые популярные жанры (топ-5). Поясните разницу.</a></span></li><li><span><a href="#Влияет-ли-рейтинг-ESRB-на-продажи-в-отдельном-регионе?" data-toc-modified-id="Влияет-ли-рейтинг-ESRB-на-продажи-в-отдельном-регионе?-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Влияет ли рейтинг ESRB на продажи в отдельном регионе?</a></span></li></ul></li><li><span><a href="#Шаг-5.-Проверьте-гипотезы" data-toc-modified-id="Шаг-5.-Проверьте-гипотезы-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Шаг 5. Проверьте гипотезы</a></span><ul class="toc-item"><li><span><a href="#Средние-пользовательские-рейтинги-платформ-Xbox-One-и-PC-одинаковые;" data-toc-modified-id="Средние-пользовательские-рейтинги-платформ-Xbox-One-и-PC-одинаковые;-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Средние пользовательские рейтинги платформ Xbox One и PC одинаковые;</a></span></li><li><span><a href="#Средние-пользовательские-рейтинги-жанров-Action-(англ.-«действие»,-экшен-игры)-и-Sports-(англ.-«спортивные-соревнования»)-разные." data-toc-modified-id="Средние-пользовательские-рейтинги-жанров-Action-(англ.-«действие»,-экшен-игры)-и-Sports-(англ.-«спортивные-соревнования»)-разные.-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные.</a></span></li><li><span><a href="#Как-вы-сформулировали-нулевую-и-альтернативную-гипотезы;" data-toc-modified-id="Как-вы-сформулировали-нулевую-и-альтернативную-гипотезы;-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Как вы сформулировали нулевую и альтернативную гипотезы;</a></span></li><li><span><a href="#Какой-критерий-применили-для-проверки-гипотез-и-почему." data-toc-modified-id="Какой-критерий-применили-для-проверки-гипотез-и-почему.-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Какой критерий применили для проверки гипотез и почему.</a></span></li></ul></li><li><span><a href="#Шаг-6.-Напишите-общий-вывод" data-toc-modified-id="Шаг-6.-Напишите-общий-вывод-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Шаг 6. Напишите общий вывод</a></span></li></ul></div>

# %% [markdown]
# # Описание проекта

# %% [markdown]
# Вы работаете в интернет-магазине «Стримчик», который продаёт по всему миру компьютерные игры. Из открытых источников доступны исторические данные о продажах игр, оценки пользователей и экспертов, жанры и платформы (например, Xbox или PlayStation). Вам нужно выявить определяющие успешность игры закономерности. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.
# Перед вами данные до 2016 года. Представим, что сейчас декабрь 2016 г., и вы планируете кампанию на 2017-й. Нужно отработать принцип работы с данными. Неважно, прогнозируете ли вы продажи на 2017 год по данным 2016-го или же 2027-й — по данным 2026 года.
# В наборе данных попадается аббревиатура ESRB (Entertainment Software Rating Board) — это ассоциация, определяющая возрастной рейтинг компьютерных игр. ESRB оценивает игровой контент и присваивает ему подходящую возрастную категорию, например, «Для взрослых», «Для детей младшего возраста» или «Для подростков».

# %% [markdown]
# **Описание данных**
#
# `Name` — название игры
# `Platform` — платформа
# `Year_of_Release` — год выпуска
# `Genre` — жанр игры
# `NA_sales` — продажи в Северной Америке (миллионы проданных копий)
# `EU_sales` — продажи в Европе (миллионы проданных копий)
# `JP_sales` — продажи в Японии (миллионы проданных копий)
# `Other_sales` — продажи в других странах (миллионы проданных копий)
# `Critic_Score` — оценка критиков (максимум 100)
# `User_Score` — оценка пользователей (максимум 10)
# `Rating` — рейтинг от организации ESRB (англ. Entertainment Software Rating Board). Эта ассоциация определяет рейтинг компьютерных игр и присваивает им подходящую возрастную категорию.
#
# Данные за 2016 год могут быть неполными.

# %% [markdown]
# ## Шаг 1. Откройте файл с данными и изучите общую информацию

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats as st

# %%
sns.set(rc={'figure.figsize':(15,10)})
pd.set_option('display.max_columns', None)
pd.options.display.float_format = '{:,.2f}'.format
plt.style.use('tableau-colorblind10')

# %%
try:
    df = pd.read_csv('C:\\Users\\Arwin77\\Documents\\Python Scripts\\games.csv', sep=',')
except FileNotFoundError:
    df = pd.read_csv('/datasets/games.csv', sep=',')

# %%
df.sample(5)
# Out:
#                                              Name Platform  Year_of_Release  \
# 10198                   Valkyrie Drive: Bhikkhuni      PSV         2,015.00
# 4391                   Wolfenstein: The New Order      PS3         2,014.00
# 15669  New Atelier Rorona: Hajimari no Monogatari      3DS         2,015.00
# 9582                        Star Wars: Clone Wars       XB         2,003.00
# 5595              Warhammer 40,000: Squad Command      PSP         2,007.00
#
#           Genre  NA_sales  EU_sales  JP_sales  Other_sales  Critic_Score  \
# 10198    Action      0.00      0.03      0.07         0.01         72.00
# 4391    Shooter      0.14      0.21      0.02         0.07           NaN
# 15669    Action      0.00      0.00      0.02         0.00           NaN
# 9582    Shooter      0.10      0.03      0.00         0.00           NaN
# 5595   Strategy      0.11      0.13      0.00         0.08         67.00
#
#       User_Score Rating
# 10198        8.5      M
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %%
df.describe()
# Out:
#        Year_of_Release  NA_sales  EU_sales  JP_sales  Other_sales  \
# count        16,446.00 16,715.00 16,715.00 16,715.00    16,715.00
# mean          2,006.48      0.26      0.15      0.08         0.05
# std               5.88      0.81      0.50      0.31         0.19
# min           1,980.00      0.00      0.00      0.00         0.00
# 25%           2,003.00      0.00      0.00      0.00         0.00
# 50%           2,007.00      0.08      0.02      0.00         0.01
# 75%           2,010.00      0.24      0.11      0.04         0.03
# max           2,016.00     41.36     28.96     10.22        10.57
#
#        Critic_Score
# count      8,137.00
# mean          68.97
# std           13.94
# min           13.00
# 25%           60.00
# 50%           71.00
# 75%           79.00
# max           98.00

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ***В колонках `_sales` очень выделяются максимальные значения...***

# %%
for i in df.columns[4:8]:
    temp = df[df[i] == df[i].max()].iloc[0, 0]
    print('Название игры с максимальным количеством продаж в регионе', i[:2], ': ', temp)
# Out:
# Название игры с максимальным количеством продаж в регионе NA :  Wii Sports
# Название игры с максимальным количеством продаж в регионе EU :  Wii Sports
# Название игры с максимальным количеством продаж в регионе JP :  Pokemon Red/Pokemon Blue
# Название игры с максимальным количеством продаж в регионе Ot :  Grand Theft Auto: San Andreas

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#
# **Вывод по разделу**
# 1. Размер данных - 16715 строк, 11 столбцов;
# 2. Типы данных - float64 (6 столбцов), object (5 столбцов);
# 3. Имеем *большое* количество пропусков в столбцах `Critic_Score` , `User_Score` , `Rating` ;
# 4. Имеем *небольшое* количество пропусков в столбце `Year_of_Release` ;
# 5. Полные дубликаты отсутствуют.
# 6. - колонку `Year_of_Release` необходимо привести к типу `datetime` ;
# 7. - колонку `User_Score` необходимо привести к `float64` .
# 8. Видим игры с наибольшим количеством продаж по регионам.
#
#
# </div>

# %% [markdown]
# ## Шаг 2. Подготовьте данные

# %% [markdown]
# ### Замените названия столбцов (приведите к нижнему регистру);

# %%
df.columns = df.columns.str.lower()
df.columns
# Out:
# Index(['name', 'platform', 'year_of_release', 'genre', 'na_sales', 'eu_sales',
#        'jp_sales', 'other_sales', 'critic_score', 'user_score', 'rating'],
#       dtype='object')

# %% [markdown]
# ### Преобразуйте данные в нужные типы. Опишите, в каких столбцах заменили тип данных и почему;

# %% [markdown]
# *столбец `year_of_release` (год релиза) должен быть в формате даты.*

# %% [markdown]
# Т.к. у нас имеются пропуски в `year_of_release` , то заменю их на значение 1900

# %%
df['year_of_release'] = df['year_of_release'].fillna(1900)

# %%
df[df['year_of_release'] == 1900].shape[0]
# Out:
# 269

# %%
df['year_of_release'] = pd.to_datetime(df['year_of_release'], format='%Y').dt.year

# %%
df['year_of_release'].head()
# Out:
# 0    2006
# 1    1985
# 2    2008
# 3    2009
# 4    1996
# Name: year_of_release, dtype: int64

# %% [markdown]
# В общем вывод: ненадо здесь формат datetime, т.к. в итоге все равно приходим к int.

# %% [markdown]
# *столбец `user_score` (оценка пользователя) должен быть типа `float64` , т.к. имеет числовое значение.*

# %%
#df['user_score'] = df['user_score'].astype('float64')
# получаем ошибку "ValueError: could not convert string to float: 'tbd'"
# тогда разберемся с значением 'tbd'... Вообще посмотрим на уникальные значения

# %%
df['user_score']
# Out:
# 0          8
# 1        NaN
# 2        8.3
# 3          8
# 4        NaN
#         ...
# 16710    NaN
# 16711    NaN
# 16712    NaN
# 16713    NaN
# 16714    NaN
# Name: user_score, Length: 16715, dtype: object

# %%
df['user_score'].unique()
# Out:
# array(['8', nan, '8.3', '8.5', '6.6', '8.4', '8.6', '7.7', '6.3', '7.4',
#        '8.2', '9', '7.9', '8.1', '8.7', '7.1', '3.4', '5.3', '4.8', '3.2',
#        '8.9', '6.4', '7.8', '7.5', '2.6', '7.2', '9.2', '7', '7.3', '4.3',
#        '7.6', '5.7', '5', '9.1', '6.5', 'tbd', '8.8', '6.9', '9.4', '6.8',
#        '6.1', '6.7', '5.4', '4', '4.9', '4.5', '9.3', '6.2', '4.2', '6',
#        '3.7', '4.1', '5.8', '5.6', '5.5', '4.4', '4.6', '5.9', '3.9',
#        '3.1', '2.9', '5.2', '3.3', '4.7', '5.1', '3.5', '2.5', '1.9', '3',
#        '2.7', '2.2', '2', '9.5', '2.1', '3.6', '2.8', '1.8', '3.8', '0',
#        '1.6', '9.6', '2.4', '1.7', '1.1', '0.3', '1.5', '0.7', '1.2',
#        '2.3', '0.5', '1.3', '0.2', '0.6', '1.4', '0.9', '1', '9.7'],
#       dtype=object)

# %%
df['user_score'].value_counts(dropna=False)
# Out:
# NaN    6701
# tbd    2424
# 7.8     324
# 8       290
# 8.2     282
#        ...
# 1.1       2
# 1.9       2
# 9.6       2
# 0         1
# 9.7       1
# Name: user_score, Length: 97, dtype: int64

# %% [markdown]
# Кроме 'tbd' ничего подозрительного нет.
# Значение 'tbd' не такое уж и редкое (2424 шт).
#
# [Ссылка на источник, что такое 'tbd'](https://fb-ru.turbopages.org/fb.ru/s/article/171345/tbd---chto-znachit-eto-sokraschenie)
#
# *расшифровывается очень просто - To Be Determined, то есть "Будет определено"*, т.е. в настоящий момент оценка отсутствует.
# Тогда можно эту абревиатуру заменить на любое число, а еще лучше NaN (это же тоже самое!).

# %%
df['user_score'].isnull().sum()
# Out:
# 6701

# %%
# здесь понадобиться numpy, добавил в первой ячейке
df['user_score'] = df['user_score'].replace('tbd', np.NaN)

# %%
df['user_score'].isnull().sum()
# Out:
# 9125

# %%
df['user_score'] = df['user_score'].astype('float64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16715 non-null  object
#  2   year_of_release  16715 non-null  int64
#  3   genre            16713 non-null  object
#  4   na_sales         16715 non-null  float64
#  5   eu_sales         16715 non-null  float64
#  6   jp_sales         16715 non-null  float64
#  7   other_sales      16715 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       7590 non-null   float64
#  10  rating           9949 non-null   object
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %% [markdown]
# ### Обработайте пропуски при необходимости;

# %%
df.isnull().sum().sort_values(ascending=False) / len(df) * 100
# Out:
# user_score        54.59
# critic_score      51.32
# rating            40.48
# name               0.01
# genre              0.01
# platform           0.00
# year_of_release    0.00
# na_sales           0.00
# eu_sales           0.00
# jp_sales           0.00
# other_sales        0.00
# dtype: float64

# %% [markdown]
# В колонках `genre` , `name` , `year_of_release` количество пропусков менее 2%, их оставим как есть.
# В колонках `rating` , `critic_score` , `user_score` существенное количество пропусков от 40% до 55%. С этими колонками надо что-то делать.
#
# [История компьютерных игр](https://ru.wikipedia.org/wiki/История_компьютерных_игр)

# %% [markdown]
# 1. Пропуски заполнять не стал, т.к. не вижу в этом смысла, из-за отсутствия какой-либо логики в соответствии с которой я мог бы это сделать. Среднее??? Медиана??? Что нам это даст?
#
# 2. Причинами пропусков могли быть, как технические проблемы (при выгрузке данных), так и отсутствие обязательности заполнения отдельных данных.
#
# 3.  Причины пропусков в столбцах с оценками экспертов, с оценками пользователей и с рейтингами: 1) до 1996 года возможно такого понятия как оценка не существовало; 2) возможно оценки и рейтинг отсутствует в случае малого количества продаж.
#     Причиной большого количества пропусков в столбце rating видимо является то, что существуют не только ESRB, но и Pan European Game Information (PEGI), Computer Entertainment Rating Organization (CERO) и прочие. А в наших данных мы имеем райтинг только от ESRB и поэтому у нас такое количество пропусков.

# %%
df[df.isnull().any(axis=1)]\
    .groupby('year_of_release')[['user_score', 'critic_score', 'rating']]\
    .agg('count')\
    .plot(kind='bar', 
          title='Распределение пропусков в оценках и рейтинге по годам',
          xlabel='Дата, год', ylabel='Количество, шт.');

# %%
# Предположим, что наличие оценок связано с годом релиза...
df.groupby('year_of_release')[['user_score', 'critic_score', 'rating']]\
    .agg('count')\
    .plot(kind='bar',
          title='Распределение количества оценок и рейтингов по годам',
          xlabel='Дата, год', ylabel='Количество, шт.');

# %%
# Предположим, что наличие оценки связано с количеством продаж...
df[(df['na_sales'] < 0.5) & (df['eu_sales'] < 0.5) & (df['jp_sales'] < 0.5)].isnull().sum()
# Out:
# name                  1
# platform              0
# year_of_release       0
# genre                 1
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       7593
# user_score         8159
# rating             5892
# dtype: int64

# %% [markdown]
# Видим, что оценки и рейтинг начали появляться примерно с 1996 года.
# Также, оценки и рейтинг отсутствуют, если имеются малые продажи.
#
# Соответственно, я бы не стал данные пропуски заполнять. Бизнесу интересны больше продажи, а там с пропусками все ОК.)

# %% [markdown]
# ### Посчитайте суммарные продажи во всех регионах и запишите их в отдельный столбец.

# %%
df['total_sales'] = df['na_sales'] + df['eu_sales'] + df['jp_sales'] + df['other_sales']

# %%
# Поиск явных дубликатов
df.duplicated().sum()
# Out:
# 0

# %%
# Поиск неявных дубликатов
df[df.duplicated(subset=['name', 'platform'], keep=False)]
# Out:
#                               name platform  year_of_release     genre  \
# 604                  Madden NFL 13      PS3             2012    Sports
# 659                            NaN      GEN             1993       NaN
# 1190   Need for Speed: Most Wanted     X360             2012    Racing
# 1591   Need for Speed: Most Wanted     X360             2005    Racing
# 1745            Sonic the Hedgehog      PS3             2006  Platform
# 4127            Sonic the Hedgehog      PS3             1900  Platform
# 5972   Need for Speed: Most Wanted       PC             2005    Racing
# 11715  Need for Speed: Most Wanted       PC             2012    Racing
# 14244                          NaN      GEN             1993       NaN
# 16230                Madden NFL 13      PS3             2012    Sports
#
#        na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 604        2.11      0.22      0.00         0.23         83.00        5.50
# ...

# %% [markdown]
# 1. Строки (659, 14244) в которых нет названия надо удалить.
# 2. Строку (16230) удаляем как дубликат строки (604).
# 3. Остальные строки оставлю как есть, т.к. игра Need for Speed: Most Wanted	в данном случае имеет два релиза (2005 и 2012 годов) и разделена по платформам. Тоже самое и с Sonic the Hedgehog.

# %%
df = df.drop(labels = [659, 14244, 16230], axis = 0)

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#
# **Вывод по разделу**
# 1. Изменены названия столбцов, в соответствии с PEP8.
# 2. Столбец year_of_release преобразован к типу int, столбец user_score преобразован к типу float.
# 3. В столбце user_score значение tbd заменено на NaN.
# 4. В столбцах genre, name, year_of_release количество пропусков менее 2%, их оставим как есть. В столбцах rating, critic_score, user_score существенное количество пропусков от 40% до 55%, тоже оставляем, т.к. логика заполнения отсутствует. Такое большое количество пропусков связано с необязательностью иметь по каждой игре оценки и рейтинга.
# 5. Добавоен новый столбец total_sales в котором посчитаны суммарные продажи.
# 6. Поиск явных дубликатов результата не дал (полные дубликаты отсутствуют). Были найдены неявные дубликаты в результате чего из данных было удалено 3 строки.
#
#
# </div>

# %% [markdown]
# ## Шаг 3. Проведите исследовательский анализ данных

# %% [markdown]
# ### Посмотрите, сколько игр выпускалось в разные годы. Важны ли данные за все периоды?

# %%
df[~df.duplicated(subset=['name', 'year_of_release'])]\
    .groupby('year_of_release')['year_of_release']\
    .agg('count')\
    .plot(kind='bar', 
          title='Количество выпущенных игр по годам',
          xlabel='Дата выпуска, год', ylabel='Количество игр, шт.');

# %%
df[~df.duplicated(subset=['name', 'year_of_release'])]\
    .groupby('year_of_release')['year_of_release']\
    .agg('count')\
    .plot(xlim=(1980, 2020), logy=True,
          title='Прирост количества игр по годам',
          xlabel='Дата выпуска, год', ylabel='Количество игр, шт.');

# %% [markdown]
# Здесь мы видим резкий рост с 1980 по 1981 года. 1980 год стал отправной точкой для по-настоящему доступных домашних компьютеров. К 1982 году количество проданных игровых систем (домашних компьютеров и игровых приставок) достигло критического количества и компьютерные развлечения резко меняют многие сферы общества.
# 1983 год стал началом мирового кризиса рынка домашних консолей, широко известный как Кризис индустрии компьютерных игр 1983 года. Кризис продолжался до 1985 года, в результате чего многие компании были вынуждены покинуть рынок.
# 1990-е годы были ознаменованы заметными инновациями в компьютерных играх. Основными достижениями называют переход от растровой графики к полностью полигональному 3D, снижение популярности аркадных игр и появление нескольких новых жанров - шутер от первого лица, стратегия в реальном времени и др.
# Весь этот рост продолжался вплоть до 2008-2009 года, когда разразился мировой финансовый кризис.

# %% [markdown]
# ### Посмотрите, как менялись продажи по платформам. Выберите платформы с наибольшими суммарными продажами и постройте распределение по годам. За какой характерный срок появляются новые и исчезают старые платформы?

# %% [markdown]
# - *как менялись продажи по платформам*

# %%
df.groupby('platform')['total_sales'].agg(total='sum')\
    .reset_index()\
    .sort_values(by='total', ascending=False)\
    .plot(x='platform', y='total', kind='bar',
          title='Количество продаж по платформам',
          xlabel='Название платформы', ylabel='Количество продаж, мил.шт.');

# %% [markdown]
# Отчетливо выделяются первые 6 платформ (PS2, X360, PS3, Wii, DS, PS). Максимальные продажи у PS2, более 1200 мил. шт.
# Хочется отметить, что платформа PS (Sony Playstation, Sony Playstation 2, Sony Playstation 3) это сила... (3 из 6).

# %% [markdown]
# - *Выберите платформы с наибольшими суммарными продажами и постройте распределение по годам*

# %%
df_platform_top = df.groupby('platform')['total_sales'].agg(total='sum')\
    .reset_index()\
    .sort_values(by='total', ascending=False)\
    .head(6)
df_platform_top
# Out:
#    platform    total
# 16      PS2 1,255.77
# 28     X360   971.42
# 17      PS3   939.64
# 26      Wii   907.51
# 4        DS   806.12
# 15       PS   730.86

# %%
df_platform_top_list = list(df_platform_top.reset_index()['platform'])

df_platform_top_year = (df.query('platform in @df_platform_top_list')
                           .groupby(['platform', 'year_of_release'])['total_sales']
                           .agg('sum')
                           .reset_index())

sns.barplot(x="year_of_release", y="total_sales",
             hue="platform", 
             data=df_platform_top_year).set_title('Распределение продаж по годам');
plt.xlabel('Дата выпуска, год')
plt.ylabel('Количество продаж, мил.шт.');

# %% [markdown]
# Здесь мы видим как Sony Playstation лидировала с 1994 по 2005 года. Пик продаж PS пришелся на 1998, PS2 на 2004 год. С 2006 по 2009 лидером был Wii. С 2010 пошел общий спад продаж по всем платформам.

# %% [markdown]
# - *За какой характерный срок появляются новые и исчезают старые платформы?*

# %% [markdown]
# Я бы сказал, что характерный срок жизни платформы это 10 лет.

# %% [markdown]
# ### Возьмите данные за соответствующий актуальный период. Актуальный период определите самостоятельно в результате исследования предыдущих вопросов. Основной фактор — эти данные помогут построить прогноз на 2017 год.

# %% [markdown]
# Актуальным периодом выберем данные начиная с 2013 года, смотри график в п.3.1 "Количество игр по годам"

# %% [markdown]
# ### Не учитывайте в работе данные за предыдущие годы.

# %%
df_actual = df[df['year_of_release'] >= 2013].reset_index(drop=True)
df_actual.head()
# Out:
#                         name platform  year_of_release         genre  \
# 0         Grand Theft Auto V      PS3             2013        Action
# 1         Grand Theft Auto V     X360             2013        Action
# 2  Call of Duty: Black Ops 3      PS4             2015       Shooter
# 3        Pokemon X/Pokemon Y      3DS             2013  Role-Playing
# 4         Grand Theft Auto V      PS4             2014        Action
#
#    na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score rating  \
# 0      7.02      9.09      0.98         3.96         97.00        8.20      M
# 1      9.66      5.14      0.06         1.41         97.00        8.10      M
# 2      6.03      5.86      0.36         2.38           NaN         NaN    NaN
# 3      5.28      4.19      4.35         0.78           NaN         NaN    NaN
# 4      3.96      6.31      0.38         1.97         97.00        8.30      M
#
#    total_sales
# 0        21.05
# 1        16.27
# 2        14.63
# ...

# %%
df_actual.shape
# Out:
# (2233, 12)

# %% [markdown]
# ### Какие платформы лидируют по продажам, растут или падают? Выберите несколько потенциально прибыльных платформ.

# %%
df_actual.groupby('platform')['total_sales'].agg('sum')\
    .sort_values(ascending=False)\
    .plot(kind='bar', title='Объемы продаж');
plt.xlabel('Название платформы')
plt.ylabel('Количество продаж, мил.шт.');

# %% [markdown]
# Абсолютный лидер по общему числу продаж с 2013 года - PS4 (более 300 мил. шт.)

# %%
df_actual_year = df_actual.groupby(['platform', 'year_of_release'])['total_sales'].agg('sum').reset_index()
sns.barplot(x='year_of_release', y='total_sales', hue='platform', 
            data=df_actual_year).set_title('Распределение продаж по годам');
plt.xlabel('Дата выпуска, год')
plt.ylabel('Количество продаж, мил.шт.');

# %%
sns.relplot(data=df_actual_year, x="year_of_release", y="total_sales",
    col="platform", col_wrap= 3, kind="line");

# %% [markdown]
# Ну что тут скажешь? Все платформы имеют тенденцию к снижению, либо стагнируют около нуля...
# Честно говоря, если это рассматривать как графики которовок акций, то я бы не на одну не поставил.)))

# %% [markdown]
# ### Постройте график «ящик с усами» по глобальным продажам игр в разбивке по платформам. Опишите результат.

# %%
sns.boxplot(data=df_actual, x='platform', y='total_sales').set_title('"Ящик с усами" для каждой платформы')
plt.xlabel('Название платформы')
plt.ylabel('Количество продаж, мил.шт.');

# %%
sns.boxplot(data=df_actual, x='platform', y='total_sales')\
    .set(ylim=(0, 0.85), title='"Ящик с усами" для каждой платформы');
plt.xlabel('Название платформы')
plt.ylabel('Количество продаж, мил.шт.');

# %%
for i in df_actual['platform'].unique():
    df_temp = df_actual[df_actual['platform'] == i]
    temp_25 = df_temp['total_sales'].describe()['25%'].round(2)
    temp_50 = df_temp['total_sales'].describe()['50%'].round(2)
    temp_75 = df_temp['total_sales'].describe()['75%'].round(2)
    temp_min = df_temp['total_sales'].describe()['min'].round(2)
    temp_max = df_temp['total_sales'].describe()['max'].round(2)
    name_max = list(df_temp[df_temp['total_sales'] == temp_max]['name'])
    print('На платформе', i, '\n половина всех игр продается тиражем от', temp_25, 'до', temp_75, 'мил.шт.')
    print(' медианное значение', temp_50, 'мил.шт.')
    print(' минимум -', temp_min, 'максимум у игры', name_max, ' -', temp_max, '\n')
    
#df_temp
# Out:
# На платформе PS3
#  половина всех игр продается тиражем от 0.04 до 0.51 мил.шт.
#  медианное значение 0.15 мил.шт.
#  минимум - 0.01 максимум у игры ['Grand Theft Auto V']  - 21.05
#
# На платформе X360
#  половина всех игр продается тиражем от 0.08 до 0.8 мил.шт.
#  медианное значение 0.26 мил.шт.
#  минимум - 0.01 максимум у игры ['Grand Theft Auto V']  - 16.27
#
# На платформе PS4
#  половина всех игр продается тиражем от 0.06 до 0.73 мил.шт.
#  медианное значение 0.2 мил.шт.
#  минимум - 0.01 максимум у игры []  - 14.63
#
# На платформе 3DS
#  половина всех игр продается тиражем от 0.04 до 0.28 мил.шт.
#  медианное значение 0.09 мил.шт.
#  минимум - 0.01 максимум у игры ['Pokemon X/Pokemon Y']  - 14.6
#
# На платформе XOne
#  половина всех игр продается тиражем от 0.06 до 0.68 мил.шт.
#  медианное значение 0.22 мил.шт.
#  минимум - 0.01 максимум у игры []  - 7.39
#
# На платформе WiiU
#  половина всех игр продается тиражем от 0.06 до 0.6 мил.шт.
#  медианное значение 0.2 мил.шт.
# ...

# %% [markdown]
# ### Посмотрите, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Постройте диаграмму рассеяния и посчитайте корреляцию между отзывами и продажами. Сформулируйте выводы.

# %%
# Популярная платформа это платформа на которой было продано больше всего игр...
df_actual.groupby('platform')['total_sales'].agg('sum').sort_values().tail(1)
# Out:
# platform
# PS4   314.14
# Name: total_sales, dtype: float64

# %%
df_actual_ps4 = df_actual[df_actual['platform'] == 'PS4'].reset_index(drop=True)

# %%
sns.jointplot(data=df_actual_ps4, x="user_score", y="total_sales", height=8);

# %%
sns.jointplot(data=df_actual_ps4, x="critic_score", y="total_sales", height=8);

# %%
df_temp = df_actual_ps4[['critic_score', 'user_score',  'total_sales']]
sns.pairplot(df_temp, diag_kind='kde', plot_kws={'alpha': 0.2});

# %%
df_temp.corr()
# Out:
#               critic_score  user_score  total_sales
# critic_score          1.00        0.56         0.41
# user_score            0.56        1.00        -0.03
# total_sales           0.41       -0.03         1.00

# %% [markdown]
# **Вывод:** Взаимосвязь между оценками пользователей и продажами игр отсутствует. Существует слабая положительная линейная взаимосвязь между оценками критиков и продажами игр.

# %% [markdown]
# ### Соотнесите выводы с продажами игр на других платформах.

# %%
for i in df_actual['platform'].unique():
    df_temp = df_actual[df_actual['platform'] == i].reset_index(drop=True)
    df_temp = df_temp[['critic_score', 'user_score',  'total_sales']]
    print(i)
    display(df_temp.corr()[2:])
    #print()
# Out:
# PS3
#              critic_score  user_score  total_sales
# total_sales          0.33        0.00         1.00
# X360
#              critic_score  user_score  total_sales
# total_sales          0.35       -0.01         1.00
# PS4
#              critic_score  user_score  total_sales
# total_sales          0.41       -0.03         1.00
# 3DS
#              critic_score  user_score  total_sales
# total_sales          0.36        0.24         1.00
# XOne
#              critic_score  user_score  total_sales
# total_sales          0.42       -0.07         1.00
# WiiU
#              critic_score  user_score  total_sales
# total_sales          0.38        0.42         1.00
# Wii
#              critic_score  user_score  total_sales
# total_sales           NaN        0.68         1.00
# PC
#              critic_score  user_score  total_sales
# total_sales          0.20       -0.09         1.00
# PSV
#              critic_score  user_score  total_sales
# ...

# %% [markdown]
# **Вывод**
# В общем на всех платформах оценка критиков имеет некоторую взаимосвязь с продажами (коэф.кор.РС=0.2, коэф.кор.XOne=0.42).
# Корреляция продаж с оценкой пользователей практически отсутствует на платформах PS3, X360, PS4, XOne, PC, PSV, а на платформах 3DS, WiiU, Wii имеет следующие значения 0.24, 0.42, 0.68 соответственно.

# %% [markdown]
# ### Посмотрите на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами?

# %%
df_actual.groupby('genre')['total_sales'].agg('sum').sort_values()\
    .plot(kind='bar', title='Распределение продаж по жанрам');

# %% [markdown]
# Необходимо учесть тот факт, что игр в жанре Экшн выпускается значительно больше, чем других (в 1,5-2 раза). Доля количества игр в жанре «стрелялок» - всего лишь 8%. Очевидно, что в жанре Экшн присутствует большое количество непопулярных игр с низкими объёмами продаж, в результате чего общий объём продаж жанра "раздут" и берётся количеством, а не качеством. Медиана учитывает не только слишком большие\маленькие значения относительно среднего, но и их количество. Поэтому брать итоговые результаты медианы или среднего более корректно.
# Общие продажи - плохая метрика для поиска наиболее прибыльного жанра. За высокими показателями общих продаж может скрываться множество мелких игр с низкими продажами. Или 2-3 звезды и куча провалов. Лучше найти жанр, где игры стабильно приносят высокий доход - для этого стоит рассмотреть средние (или медианные продажи).

# %%
df_actual.groupby('genre')['total_sales'].agg('median').sort_values()\
    .plot(kind='bar', title='Распределение продаж по жанрам');
plt.xlabel('Название жанра')
plt.ylabel('Медианное значение, мил.шт.');

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'>
#
# **Вывод по разделу**
# Мы видим два кризиса в 1983 и 2008 годов.
# Платформы лидеры по продажам PS2, X360, PS3, Wii, DS, PS.
# Характерный срок жизни платформы это 10 лет.
# Актуальным периодом данных, для дальнейшего анализа, определен период, начиная с 2013 года.
# Абсолютный лидер по общему числу продаж с 2013 года - PS4 (более 300 мил. шт.).
# В общем на всех платформах оценка критиков имеет некоторую взаимосвязь с продажами (коэф.кор.РС=0.2, коэф.кор.XOne=0.42). Корреляция продаж с оценкой пользователей практически отсутствует на платформах PS3, X360, PS4, XOne, PC, PSV, а на платформах 3DS, WiiU, Wii имеет следующие значения 0.24, 0.42, 0.68 соответственно.
# Жанр игр, лучше всех приносящий доход это `Shooter` , а вот с жанром `Adventure` лучше не связываться. В тройку лидеров входят следующие жанры: `Shooter` , `Sports` , `Platform` .
#     </font>
# </div>

# %% [markdown]
# ## Шаг 4. Составьте портрет пользователя каждого региона

# %% [markdown]
# Определите для пользователя каждого региона (NA, EU, JP):

# %%
region_sales = ['na_sales', 'eu_sales', 'jp_sales']
region = ['Северная Америка', 'Европа', 'Япония']

# %% [markdown]
# ### Самые популярные платформы (топ-5). Опишите различия в долях продаж.

# %%
fig, axes = plt.subplots(1, 3)
j = 0
for i in region_sales:
    df_temp = df_actual.groupby('platform')[[i, 'total_sales']].agg('sum')\
                        .sort_values(ascending=False, by=i).reset_index().head(5)
    df_temp['fraction'] = df_temp[i] / df_temp['total_sales']
    display('ТОП-5 платформ в ' + region[j], df_temp)
    sns.barplot(data=df_temp, x='platform', y=i, ax=axes[j]).set(title='ТОП-5 платформ\n' + region[j]);
    j += 1
# Out:
# 'ТОП-5 платформ в Северная Америка'
#   platform  na_sales  total_sales  fraction
# 0      PS4    108.74       314.14      0.35
# 1     XOne     93.12       159.32      0.58
# 2     X360     81.66       136.80      0.60
# 3      PS3     63.50       181.43      0.35
# 4      3DS     38.20       143.25      0.27
# 'ТОП-5 платформ в Европа'
#   platform  eu_sales  total_sales  fraction
# 0      PS4    141.09       314.14      0.45
# 1      PS3     67.81       181.43      0.37
# 2     XOne     51.59       159.32      0.32
# 3     X360     42.52       136.80      0.31
# 4      3DS     30.96       143.25      0.22
# 'ТОП-5 платформ в Япония'
#   platform  jp_sales  total_sales  fraction
# 0      3DS     67.81       143.25      0.47
# 1      PS3     23.35       181.43      0.13
# 2      PSV     18.59        32.99      0.56
# 3      PS4     15.96       314.14      0.05
# 4     WiiU     10.88        64.63      0.17

# %%
fig = plt.figure(figsize=(20, 7))
fig.suptitle('Лидеры продаж', fontsize=20)

j = 0
for i in region_sales:
    j += 1
    plt.subplot(1, 3, j)
    df_temp = df_actual.groupby('genre')[[i, 'total_sales']].agg('median')\
                        .sort_values(ascending=False, by=i).head(5)
    df_temp[i].head(5)\
        .plot(kind='pie', autopct='%1.1f%%', explode=(0.1,0.1,0,0,0.1), labeldistance=None,
              title=region[j-1], fontsize=15)
    plt.legend(loc='center', bbox_to_anchor=(1.0,-0.01))
    plt.ylabel('')

# %% [markdown]
# **Вывод**
# Платформы PS4, PS3, 3DS присутствуют во всех регионах. Наибольшие продажи PS4, PS3 происходят в Свеверной Америке и Европе, а 3DS в Японии. Такие платформы как XOne, X360 представленны только в Свеверной Америке и Европе, а платформы PSV, WiiU представлены только в Японии.

# %% [markdown]
# ### Самые популярные жанры (топ-5). Поясните разницу.

# %%
fig, axes = plt.subplots(1, 3)
j = 0
for i in region_sales:
    df_temp = df_actual.groupby('genre')[[i, 'total_sales']].agg('sum')\
                        .sort_values(ascending=False, by=i).reset_index().head(5)
    df_temp['fraction'] = df_temp[i] / df_temp['total_sales']
    display('ТОП-5 жанров в ' + region[j], df_temp)
    sns.barplot(data=df_temp, x='genre', y=i, ax=axes[j]).set(title='ТОП-5 жанров\n' + region[j]);
    j += 1
# Out:
# 'ТОП-5 жанров в Северная Америка'
#           genre  na_sales  total_sales  fraction
# 0        Action    126.05       321.87      0.39
# 1       Shooter    109.74       232.98      0.47
# 2        Sports     65.27       150.65      0.43
# 3  Role-Playing     46.40       145.89      0.32
# 4          Misc     27.49        62.82      0.44
# 'ТОП-5 жанров в Европа'
#           genre  eu_sales  total_sales  fraction
# 0        Action    118.13       321.87      0.37
# 1       Shooter     87.86       232.98      0.38
# 2        Sports     60.52       150.65      0.40
# 3  Role-Playing     36.97       145.89      0.25
# 4        Racing     20.19        39.89      0.51
# 'ТОП-5 жанров в Япония'
#           genre  jp_sales  total_sales  fraction
# 0  Role-Playing     51.04       145.89      0.35
# 1        Action     40.49       321.87      0.13
# 2          Misc      9.20        62.82      0.15
# 3      Fighting      7.65        35.31      0.22
# ...

# %%
fig = plt.figure(figsize=(20, 7))
fig.suptitle('Лидеры продаж', fontsize=20)
j = 0
for i in region_sales:
    j += 1
    plt.subplot(1, 3, j)
    df_temp = df_actual.groupby('genre')[[i, 'total_sales']].agg('median')\
                        .sort_values(ascending=False, by=i).head(5)
    df_temp[i].head(5)\
        .plot(kind='pie', autopct='%1.1f%%', explode=(0.1,0.1,0,0,0.1), labeldistance=None,
          title=region[j-1], fontsize=15)
    plt.legend(loc='center', bbox_to_anchor=(1.0,-0.01))
    plt.ylabel('')

# %% [markdown]
# **Вывод**
# Северная Америка и Европа практически одинаковы в своих предпочтениях, лидер жанра `Action` , в то время как в Японии лидер - `Role-Playing`.

# %% [markdown]
# ### Влияет ли рейтинг ESRB на продажи в отдельном регионе?

# %% [markdown]
# [Почитать про ESRB](https://ru.wikipedia.org/wiki/Entertainment_Software_Rating_Board)

# %%
df_actual['rating'].value_counts(dropna=False)
# Out:
# NaN     977
# M       369
# T       333
# E       302
# E10+    252
# Name: rating, dtype: int64

# %%
df_actual['rating'] = df_actual['rating'].fillna('NO_rating')

# %%
df_actual.groupby('rating')[['na_sales', 'eu_sales', 'jp_sales']].agg('sum')
# Out:
#            na_sales  eu_sales  jp_sales
# rating
# E             79.05     83.36     15.14
# E10+          54.24     42.69      5.89
# M            165.21    145.32     14.11
# NO_rating     89.42     78.91     85.05
# T             49.79     41.95     20.59

# %% [markdown]
# **Вывод** Лидеры продаж в Северной Америке и Европе - игры с рейтингом "Для взрослых" (165.21 и 145.32 мил.шт.), в Японии - игры без рейтинга.
# Аутсайдерами в Северной Америке и Европе значится рейтинг "Подросткам", в Японии - "Для всех от 10 лет и старше". Получается, что в Северной Америке и Европе большинство пользователей в возрасте от 17 лет.
# В Японии свое рейтинговое агенство CERO, а в наших данных имеются рейтинги только от американскаго ESRB агенства.

# %% [markdown]
# ## Шаг 5. Проверьте гипотезы

# %% [markdown]
# ### Средние пользовательские рейтинги платформ Xbox One и PC одинаковые;

# %%
df_xbox = df_actual[df_actual['platform'] == 'XOne']

df_pc = df_actual[df_actual['platform'] == 'PC']

# %% [markdown]
# **H_0:** Средний пользовательский рейтинг `user_score`платформы Xbox One = Среднему пользовательскому рейтингу `user_score`платформы РС.
#
# **H_a:** Средний пользовательский рейтинг `user_score`платформы Xbox One ≠ Среднему пользовательскому рейтингу `user_score`платформы РС.
#
# alpha = 0.05

# %%
results = st.ttest_ind(df_xbox['user_score'].dropna(), df_pc['user_score'].dropna(), equal_var=False)
alpha = 0.05
print(results.pvalue)
if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# 0.14759594013430463
# Не получилось отвергнуть нулевую гипотезу

# %%
sns.histplot(data=df_xbox['user_score'], kde=True, color='green')
sns.histplot(data=df_pc['user_score'], kde=True, color='blue');

# %% [markdown]
# ### Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные.

# %%
df_action = df_actual[df_actual['genre'] == 'Action']

df_sports = df_actual[df_actual['genre'] == 'Sports']

# %% [markdown]
# **H_0:** Средний пользовательский рейтинг `user_score` жанра Action = Среднему пользовательскому рейтингу `user_score` жанра Sports.
#
# **H_a:** Средний пользовательский рейтинг `user_score` жанра Action ≠ Среднему пользовательскому рейтингу `user_score` жанра Sports.
#
# alpha = 0.05

# %%
results = st.ttest_ind(df_action['user_score'].dropna(), df_sports['user_score'].dropna(), equal_var=False)
alpha = 0.05
print(results.pvalue)
if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# 1.4460039700704315e-20
# Отвергаем нулевую гипотезу

# %%
sns.histplot(data=df_action['user_score'], kde=True, color='green')
sns.histplot(data=df_sports['user_score'], kde=True, color='blue');

# %% [markdown]
# ### Как вы сформулировали нулевую и альтернативную гипотезы;

# %% [markdown]
# Гипотеза Н_0 (нулевая) это предположение о равенстве среднего в двух выборках.
# Гипотеза Н_а (альтернативная) это, которая говорит об обратном.

# %% [markdown]
# ### Какой критерий применили для проверки гипотез и почему.

# %% [markdown]
# [t-критерий Стьюдента](https://ru.wikipedia.org/wiki/T-критерий_Стьюдента)
#
# t-критерий Стьюдента — общее название для класса методов статистической проверки гипотез (статистических критериев), основанных на распределении Стьюдента. Наиболее частые случаи применения t-критерия связаны с проверкой равенства средних значений в двух выборках.

# %% [markdown]
# ## Шаг 6. Напишите общий вывод

# %%
names = ['Северная Америка', 'Европа', 'Япония', 'Остальные']
plt.figure(figsize=(5, 5))
df_actual[['na_sales', 'eu_sales', 'jp_sales', 'other_sales']].sum()\
    .plot(kind='pie', labels=names, wedgeprops = {'linewidth' : 3, 'edgecolor' : 'white'},
          title='Круговая диаграма глобальных продаж', fontsize=15, autopct='%1.1f%%');

my_circle=plt.Circle( (0,0), 0.7, color='white')
p=plt.gcf()
p.gca().add_artist(my_circle);

# %%
df_actual[['na_sales', 'eu_sales', 'jp_sales', 'other_sales']].sum()
# Out:
# na_sales      437.71
# eu_sales      392.23
# jp_sales      140.78
# other_sales   119.97
# dtype: float64

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#
# **Вывод:**
# Количество выпускаемых игр в последние годы снижается, возможно это связано с качеством и сложностью разработки. Виден конец жизненного цикла всех топовых платформ.
# За последние четыре года на первом месте по глобальным продажам находится Северная Америка - 438 мил.шт., на втором Европа - 392 мил.шт., на третьем Япония - 141 мил.шт.
# Платформы лидеры по продажам в 2016 году - PS4, Xone, X360.
# На всех платформах оценка критиков имеет слабую линейную взаимосвязь с продажами (коэф.кор.РС=0.2, коэф.кор.XOne=0.42).
# Корреляция продаж с оценкой пользователей практически отсутствует на платформах PS3, X360, PS4, XOne, PC, PSV, а на платформах 3DS, WiiU, Wii имеет следующие значения 0.24, 0.42, 0.68 соответственно.
# В тройку лидеров входят следующие жанры: Shooter, Sports, Platform. Жанр игр, лучше всех приносящий доход это Shooter, а вот с жанром Adventure лучше не связываться.
# Платформы PS4, PS3, 3DS присутствуют во всех регионах. Наибольшие продажи PS4, PS3 происходят в Свеверной Америке и Европе, а 3DS в Японии. Такие платформы как XOne, X360 представленны только в Свеверной Америке и Европе, а платформы PSV, WiiU представлены только в Японии.
# Лидеры продаж в Северной Америке и Европе - игры с рейтингом "Для взрослых" (165.21 и 145.32 мил.шт.), в Японии - игры без рейтинга. Аутсайдерами в Северной Америке и Европе значится рейтинг "Подросткам", в Японии - "Для всех от 10 лет и старше". Получается, что в Северной Америке и Европе большинство пользователей в возрасте от 17 лет.
# В данных присутствует рейтинг только от американской компании (ESRB), необходимо добавить рейтинги от европейской (PEGI) и японской компаний (CERO).
#
# **Наиболее прибыльным является рынок Америки, жанр Shooter, платформа PS4, игры с рейтингом "Для взрослых".**
#
# </div>
